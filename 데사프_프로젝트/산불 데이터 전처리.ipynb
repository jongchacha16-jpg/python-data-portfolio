# %%
import csv

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3d15358b-1435-48e8-946f-f6efd9845e06" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3d15358b-1435-48e8-946f-f6efd9845e06">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f84e24d7-9015-4a09-adc2-ebb3ce9c0fff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f84e24d7-9015-4a09-adc2-ebb3ce9c0fff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("wildfire_data.csv")
df
# Out:
#        Unnamed: 0 region        date  wildfire  ave_temp  min_temp  max_temp  \
# 0               0    강릉시  2012-01-01         0       0.8      -1.8       4.5
# 1               1    고성군  2012-01-01         0       1.1      -1.5       4.9
# 2               2    동해시  2012-01-01         0       1.6      -1.1       5.3
# 3               3    삼척시  2012-01-01         0       1.6      -1.1       5.3
# 4               4    속초시  2012-01-01         0       1.1      -1.5       4.9
# ...           ...    ...         ...       ...       ...       ...       ...
# 65855       65855    태백시  2021-12-31         0      -9.9     -12.8      -5.6
# 65856       65856    평창군  2021-12-31         0     -11.8     -14.7      -7.3
# 65857       65857    홍천군  2021-12-31         0      -7.3     -11.7      -3.1
# 65858       65858    화천군  2021-12-31         0      -9.1     -13.7      -4.6
# 65859       65859    횡성군  2021-12-31         0      -5.6      -8.8      -2.4
#
# ...

# %%
df_1 = pd.read_excel("주요관광지점 입장객_2.xls")
df_1
# Out:
#      시도   군구            관광지 내/외국인  총계(2012.01 ~ 2021.12)    2012년 Unnamed: 6  \
# 0   NaN  NaN            NaN   NaN                    NaN      인원계  2012년 01월
# 1   강원도  춘천시     국립용화산자연휴양림    합계               681050.0    73644       2600
# 2   강원도  원주시       백운산자연휴양림    합계               927367.0   110695       7682
# 3   강원도  원주시       치악산 국립공원    합계               533771.0   533771      27825
# 4   강원도  원주시       치악산자연휴양림    합계               325022.0    24213       1257
# 5   강원도  강릉시     오대산국립공원소금강    합계              1165086.0   175362       2548
# 6   강원도  태백시        태백산국립공원    합계              5711495.0   624952     226388
# 7   강원도  속초시   설악산국립공원(설악동)    합계             21061220.0  2718625     165596
# 8   강원도  홍천군       가리산자연휴양림    합계               388584.0    50414       2616
# 9   강원도  홍천군         팔봉산관광지    합계               612431.0    75017          0
# 10  강원도  횡성군       청태산자연휴양림    합계               164117.0   164117      10237
# ...

# %%
# Out:
# 0         인원계
# 1       73644
# 2      110695
# 3      533771
# 4       24213
# 5      175362
# 6      624952
# 7     2718625
# 8       50414
# 9       75017
# 10     164117
# 11     100655
# 12      47867
# 13        NaN
# 14    1109779
# 15      76140
# 16     462155
# 17      42117
# 18      64198
# 19        NaN
# 20     434553
# Name: 2012년, dtype: object
